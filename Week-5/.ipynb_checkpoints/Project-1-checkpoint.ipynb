# %%
import tkinter as tk
from tkinter import messagebox
import csv


# Data of employees
data = {"First name": [], "Surname": [], "Department": [], "S/N": []}
file_path = r"C:\Users\dasil\OneDrive\Documents\O.Da-silvaCOS102\Week-5\GIG-logistics.csv"
with open(file_path,"r") as file:
    csv_reader = csv.reader(file)
    for i in csv_reader:
        data["First name"].append(i[2])
        data["Surname"].append(i[1])
        data["Department"].append(i[3])
        data["S/N"].append(i[0])

Sname = data["Surname"]
Fname = data["First name"]
Dept = data["Department"]
# login window
def welcomeMessage(username):
    # Create a Tkinter window
    window = tk. Toplevel(root)
    window.title("Admin Box")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {username}\n")
    label_1.pack()

    if Dept == Dept:
        label_2 = tk.Label(window, text="Signed in: These are the members of your Department :")
        label_2.pack()

    # Run the Tkinter event Loop
    root.mainloop()

def submit():
    Sname = Sname_entry.get()
    Fname = Fname_entry.get()
    Dept = Dept_entry.get()

    for i in Dept:
        if Sname == Sname and Fname == Fname and Dept == Dept:
            welcomeMessage(Fname)              
        else:
            messagebox.showerror("Login", "Not an existing Employee")

# Create main window
root = tk.Tk()
root.title("Login Form")
root.geometry("800x200")

# Create Surname label and entry
Sname_label = tk. Label(root, text="Surname:")
Sname_label.pack()
Sname_entry = tk.Entry(root)
Sname_entry.pack()

# Create Firstname label and entry
Fname_label = tk. Label(root, text="Firstname:")
Fname_label.pack()
Fname_entry = tk.Entry(root)
Fname_entry.pack()

# Create Department label and entry
Dept_label = tk. Label(root, text="Department:")
Dept_label.pack()
Dept_entry = tk.Entry(root)
Dept_entry.pack()

# Create submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event Loop
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\dasil\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\dasil\AppData\Local\Temp\ipykernel_4420\3768036525.py", line 44, in submit
#     welcomeMessage(Fname)
#   File "C:\Users\dasil\AppData\Local\Temp\ipykernel_4420\3768036525.py", line 23, in welcomeMessage
#     window = tk. Toplevel(root)
#              ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dasil\anaconda3\Lib\tkinter\__init__.py", line 2677, in __init__
#     BaseWidget.__init__(self, master, 'toplevel', cnf, {}, extra)
#   File "C:\Users\dasil\anaconda3\Lib\tkinter\__init__.py", line 2628, in __init__
#     self.tk.call(
# _tkinter.TclError: can't invoke "toplevel" command: application has been destroyed
