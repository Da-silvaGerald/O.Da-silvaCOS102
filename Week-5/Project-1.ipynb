# %%
import tkinter as tk
from tkinter import messagebox
import csv


# Data of employees
data = {"FIRST NAME": [], "SURNAME": [], "DEPARTMENT": [], "S/N": []}
file_path = r"C:\Users\dasil\OneDrive\Documents\O.Da-silvaCOS102\Week-5\GIG-logistics.csv"
with open(file_path,"r") as file:
    csv_reader = csv.reader(file)
    for i in csv_reader:
        data["FIRSTNAME"].append(i[2])
        data["SURNAME"].append(i[1])
        data["DEPARTMENT"].append(i[3])
        data["S/N"].append(i[0])

surname = data["SURNAME"]
firstname = data["FIRST NAME"]
department = data["DEPARTMENT"]
# login window
def welcomeMessage(Fname, Sname):
    # Create a Tkinter window
    window = tk. Toplevel(root)
    window.title("Admin Box")
    window.geometry("500x200")
    
    if Dept == Dept:
        label_1 = tk.Label(window, text="Signed in")
        label_1.pack()


        label_2 = tk.Label(window, text=f"Welcome {Sname},{Fname}, Here are the members of your Department: \n")
        label_2.pack()

    
    # Run the Tkinter event Loop
    root.mainloop()

def submit():
    Sname = Sname_entry.get()
    Fname = Fname_entry.get()
    Dept = Dept_entry.get()

    for i in Dept:
        if Sname == surname[i] and Fname ==firstname[i] and Dept == department[i] :
            welcomeMessage(Fname,Sname)              
        else:
            messagebox.showerror("Login", "Not an existing Employee")

# Create main window
root = tk.Tk()
root.title("Login Form")
root.geometry("800x200")

# Create Surname label and entry
Sname_label = tk. Label(root, text="Surname:")
Sname_label.pack()
Sname_entry = tk.Entry(root)
Sname_entry.pack()

# Create Firstname label and entry
Fname_label = tk. Label(root, text="Firstname:")
Fname_label.pack()
Fname_entry = tk.Entry(root)
Fname_entry.pack()

# Create Department label and entry
Dept_label = tk. Label(root, text="Department:")
Dept_label.pack()
Dept_entry = tk.Entry(root)
Dept_entry.pack()

# Create submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event Loop
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 12
#      10 csv_reader = csv.reader(file)
#      11 for i in csv_reader:
# ---> 12     data["FIRSTNAME"].append(i[2])
#      13     data["SURNAME"].append(i[1])
#      14     data["DEPARTMENT"].append(i[3])
#
# KeyError: 'FIRSTNAME'
