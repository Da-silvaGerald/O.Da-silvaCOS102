# %%
# Python GUI for Simi Services
import tkinter as tk
from tkinter import messagebox


def type1(firstname,surname):
    # Create a Tkinter window
    window = tk. Toplevel(root)
    window.title("Admin Box")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {firstname,surname}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="Your balance is N3500")
    label_2.pack()

    # Run the Tkinter event Loop
    root.mainloop()

def type2(firstname,surname):
    # Create a Tkinter window
    window = tk. Toplevel(root)
    window.title("Admin Box")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {firstname,surname}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="Your balance is N5000")
    label_2.pack()

    # Run the Tkinter event Loop
    root.mainloop()

def type3(firstname,surname):
    # Create a Tkinter window
    window = tk. Toplevel(root)
    window.title("Admin Box")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {firstname},{surname}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="Your balance is N10000")
    label_2.pack()

    # Run the Tkinter event Loop
    root.mainloop()

def enter():
    location = location_entry.get()
    weight = weight_entry.get()
    firstname = firstname_entry.get()
    surname = surname_entry.get()

    if location == "ibeju-lekki" and int(weight) >= 10:
        type2(firstname,surname)
    elif location == "ibeju-lekki" and int(weight) < 10:
        type1(firstname,surname)
    elif location == "epe" and int(weight) >=10:
        type3(firstname,surname)
    elif locatiom == "epe" and int(weight) < 10:
        type2(firstname,surname)
    else:
        messagebox.showerror("Login", "Invalid Location or Weight")

# Create main window
root = tk. Tk()
root. title("Login Form")
root.geometry("500x200")


# Create firstname Label and entry
firstname_label = tk. Label(root, text="Firstname:")
firstname_label.pack()
firstname_entry = tk. Entry(root)
firstname_entry.pack()

# Create surname label and entry
surname_label = tk.Label(root, text="Surname:")
surname_label.pack()
surname_entry = tk.Entry(root)
surname_entry.pack()

# Create address label and entry
location_label = tk.Label(root, text="Location:")
location_label.pack()
location_entry = tk.Entry(root)
location_entry.pack()

# Create weight label and entry
weight_label = tk.Label(root, text="Weight of Package(KG):")
weight_label.pack()
weight_entry = tk.Entry(root)
weight_entry.pack()

# Create enter/submit button
enter_button = tk.Button(root, text="Enter", command=enter)
enter_button.pack()

# Run the main event Loop
root.mainloop()

# %%
# Python GUI for Computer Science and Mass comm admission
import tkinter as tk
from tkinter import messagebox

def enter():
    course = course_entry.get()

    if course == "Mass Communication":

        def message1(firstname,surname):
            # Create a Tkinter window
            window = tk. Toplevel(massc)
            window.title("Admin Box")
            window.geometry("500x200")

            label_1 = tk.Label(window, text=f"Welcome {firstname},{surname}\n")
            label_1.pack()
            label_2 = tk.Label(window, text="You have been admitted to study mass comm")
            label_2.pack()
        def message2(firstname,surname):
            # Create a Tkinter window
            window = tk. Toplevel(massc)
            window.title("Admin Box")
            window.geometry("500x200")

            label_1 = tk.Label(window, text=f"Welcome {firstname},{surname}\n")
            label_1.pack()
            label_2 = tk.Label(window, text="You are not eligible to study mass comm")
            label_2.pack()

            # Run the Tkinter event Loop
            root.mainloop()
        def submit1():
            interview = interview_entry.get()
            jamb = jamb_entry.get()
            firstname = firstname_entry.get()
            surname = surname_entry.get()
            math = math_entry.get()
            english = english_entry.get()
            literature = literature_entry.get()
            government = government_entry.get()
            history = history_entry.get()
            
            if interview == "Yes" and int(jamb) >= 230 and int(math) >=60 and int(english) >=60 and int(literature) >=60 and int(government) >=60 and int(history) >=60:
                admitted = []
                a = (firstname,surname)
                admitted = [a]
                message1(firstname,surname)
            else:
                not_admitted = []
                na = (firstname,surname)
                not_admitted = [na]
                message2(firstname,surname)

        # Create main window
        massc = tk. Tk()
        massc.title("Mass Communication Login Form")
        massc.geometry("500x200")

        # Create interview Label and entry
        interview_label = tk. Label(massc, text="Did you pass the interview?:")
        interview_label.pack()
        interview_entry = tk. Entry(massc)
        interview_entry.pack()    
                
        # Create Jamb Label and entry
        jamb_label = tk. Label(massc, text="Jamb Score:")
        jamb_label.pack()
        jamb_entry = tk. Entry(massc)
        jamb_entry.pack()     
   
        # Create Math Label and entry
        math_label = tk. Label(massc, text="Math Score:")
        math_label.pack()
        math_entry = tk. Entry(massc)
        math_entry.pack()

        # Create English Label and entry
        english_label = tk. Label(massc, text="English score:")
        english_label.pack()
        english_entry = tk. Entry(massc)
        english_entry.pack()

        # Create Literature Label and entry
        literature_label = tk. Label(massc, text="Literature Score:")
        literature_label.pack()
        literature_entry = tk. Entry(massc)
        literature_entry.pack()

        # Create Government Label and entry
        government_label = tk. Label(massc, text="Government Score:")
        government_label.pack()
        government_entry = tk. Entry(massc)
        government_entry.pack()

        # Create History Label and entry
        history_label = tk. Label(massc, text="History Score:")
        history_label.pack()
        history_entry = tk. Entry(massc)
        history_entry.pack()

        # Create enter/submit button
        submit1_button = tk.Button(massc, text="Submit", command=submit1)
        submit1_button.pack()

        # Run the main event Loop
        massc.mainloop()

    elif course == "Computer Science":

        def message3(firstname,surname):
            # Create a Tkinter window
            window = tk. Toplevel(comsc)
            window.title("Admin Box")
            window.geometry("500x200")

            label_1 = tk.Label(window, text=f"Welcome {firstname},{surname}\n")
            label_1.pack()
            label_2 = tk.Label(window, text="You have been admitted to study Computer Science")
            label_2.pack()
            
        def message4(firstname,surname):
            # Create a Tkinter window
            window = tk. Toplevel(comsc)
            window.title("Admin Box")
            window.geometry("500x200")

            label_1 = tk.Label(window, text=f"Welcome {firstname},{surname}\n")
            label_1.pack()
            label_2 = tk.Label(window, text="You are not eligible to study Computer Science")
            label_2.pack()

            # Run the Tkinter event Loop
            root.mainloop()
        def submit2():
            interview = interview_entry.get()
            jamb = jamb_entry.get()
            firstname = firstname_entry.get()
            surname = surname_entry.get()
            math = math_entry.get()
            english = english_entry.get()
            chemistry = chemistry_entry.get()
            fmath = fmath_entry.get()
            physics = physics_entry.get()
            
            if interview =="Yes" and int(jamb)>= 250 and int(math) >=60 and int(english) >=60 and int(chemistry) >=60 and int(fmath) >=60 and int(physics) >=60:
                admitted = []
                a = (firstname,surname)
                admitted = [a]
                message3(firstname,surname)
            else:
                not_admitted = []
                na = (firstname,surname)
                not_admitted = [na]
                message4(firstname,surname) 

        # Create main window
        comsc = tk. Tk()
        comsc.title("Computer Science Login Form")
        comsc.geometry("500x200")

        # Create Interview Label and entry
        interview_label = tk. Label(comsc, text="Did you pass the interview?")
        interview_label.pack()
        interview_entry = tk. Entry(comsc)
        interview_entry.pack()

        # Create Jamb Label and entry
        jamb_label = tk. Label(comsc, text="Jamb  Score:")
        jamb_label.pack()
        jamb_entry = tk. Entry(comsc)
        jamb_entry.pack()     

        # Create Math Label and entry
        math_label = tk. Label(comsc, text="Math Score:")
        math_label.pack()
        math_entry = tk. Entry(comsc)
        math_entry.pack()

        # Create English Label and entry
        english_label = tk. Label(comsc, text="English score:")
        english_label.pack()
        english_entry = tk. Entry(comsc)
        english_entry.pack()

        # Create Chemistry Label and entry
        chemistry_label = tk. Label(comsc, text="Chemistry Score:")
        chemistry_label.pack()
        chemistry_entry = tk. Entry(comsc)
        chemistry_entry.pack()

        # Create Further Mathematics Label and entry
        fmath_label = tk. Label(comsc, text="Further Mathematics Score:")
        fmath_label.pack()
        fmath_entry = tk. Entry(comsc)
        fmath_entry.pack()

        # Create Physics Label and entry
        physics_label = tk. Label(comsc, text="Physics Score:")
        physics_label.pack()
        physics_entry = tk. Entry(comsc)
        physics_entry.pack()

        # Create enter/submit button
        submit2_button = tk.Button(comsc, text="Enter", command=submit2)
        submit2_button.pack()

        # Run the main event Loop
        comsc.mainloop()
    else:
        messagebox.showerror("Login", "Course not offered")

# Create main window
root = tk. Tk()
root. title("Login Form")
root.geometry("500x200")


# Create firstname Label and entry
firstname_label = tk. Label(root, text="Firstname:")
firstname_label.pack()
firstname_entry = tk. Entry(root)
firstname_entry.pack()

# Create surname label and entry
surname_label = tk.Label(root, text="Surname:")
surname_label.pack()
surname_entry = tk.Entry(root)
surname_entry.pack()

# Create course label and entry
course_label = tk.Label(root, text="Course to be Studied:")
course_label.pack()
course_entry = tk.Entry(root)
course_entry.pack()

# Create enter/submit button
enter_button = tk.Button(root, text="Enter", command=enter)
enter_button.pack()

# Run the main event Loop
root.mainloop()
